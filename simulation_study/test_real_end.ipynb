# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service_ibm = QiskitRuntimeService()
real_backend = None
real_backend = service_ibm.least_busy(operational=True, simulator=False)
print(f"[Q-Safe BO (Real)] Selected backend: {real_backend.name}")
# Out:
# ---------------------------------------------------------------------------
# QiskitBackendNotFoundError                Traceback (most recent call last)
# Cell In[3], line 5
#       3 service_ibm = QiskitRuntimeService()
#       4 real_backend = None
# ----> 5 real_backend = service_ibm.least_busy(operational=True, simulator=False)
#       6 print(f"[Q-Safe BO (Real)] Selected backend: {real_backend.name}")
#
# File ~/anaconda3/envs/quantum/lib/python3.8/site-packages/qiskit_ibm_runtime/qiskit_runtime_service.py:1164, in QiskitRuntimeService.least_busy(self, min_num_qubits, instance, filters, **kwargs)
#    1162     candidates.append(back)
#    1163 if not candidates:
# -> 1164     raise QiskitBackendNotFoundError("No backend matches the criteria.")
#    1165 return min(candidates, key=lambda b: b.status().pending_jobs)
#
# QiskitBackendNotFoundError: 'No backend matches the criteria.'
